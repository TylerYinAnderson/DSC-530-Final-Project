# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import thinkstats2
import thinkplot

df = pd.read_csv('bad-drivers.csv')

fatal_billion = df['Number of drivers involved in fatal collisions per billion miles']
fatal_speed = df['Percentage Of Drivers Involved In Fatal Collisions Who Were Speeding']
fatal_alcoholimpared = df['Percentage Of Drivers Involved In Fatal Collisions Who Were Alcohol-Impaired']
fatal_notdistracted = df['Percentage Of Drivers Involved In Fatal Collisions Who Were Not Distracted']
fatal_notprevaccidents = df['Percentage Of Drivers Involved In Fatal Collisions Who Had Not Been Involved In Any Previous Accidents']

# %%
import statsmodels.formula.api as smf

# %%
formula = 'fatal_speed ~ fatal_alcoholimpared'
model = smf.ols(formula, data=df)
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            fatal_speed   R-squared:                       0.082
# Model:                            OLS   Adj. R-squared:                  0.063
# Method:                 Least Squares   F-statistic:                     4.373
# Date:                Sat, 01 Jun 2019   Prob (F-statistic):             0.0417
# Time:                        18:38:11   Log-Likelihood:                -185.21
# No. Observations:                  51   AIC:                             374.4
# Df Residuals:                      49   BIC:                             378.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Intercept               15.2379      7.992      1.907      0.062      -0.822      31.298
# fatal_alcoholimpared     0.5373      0.257      2.091      0.042       0.021       1.054
# ==============================================================================
# Omnibus:                        0.651   Durbin-Watson:                   1.750
# Prob(Omnibus):                  0.722   Jarque-Bera (JB):                0.752
# Skew:                          -0.145   Prob(JB):                        0.686
# Kurtosis:                       2.481   Cond. No.                         191.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
formula = 'fatal_speed ~ fatal_alcoholimpared + fatal_billion'
results = smf.ols(formula, data=df).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            fatal_speed   R-squared:                       0.090
# Model:                            OLS   Adj. R-squared:                  0.052
# Method:                 Least Squares   F-statistic:                     2.364
# Date:                Sat, 01 Jun 2019   Prob (F-statistic):              0.105
# Time:                        18:43:28   Log-Likelihood:                -184.99
# No. Observations:                  51   AIC:                             376.0
# Df Residuals:                      48   BIC:                             381.8
# Df Model:                           2
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Intercept               17.5186      8.798      1.991      0.052      -0.171      35.208
# fatal_alcoholimpared     0.5709      0.264      2.164      0.035       0.040       1.101
# fatal_billion           -0.2097      0.328     -0.639      0.526      -0.870       0.451
# ==============================================================================
# Omnibus:                        0.513   Durbin-Watson:                   1.726
# Prob(Omnibus):                  0.774   Jarque-Bera (JB):                0.656
# Skew:                          -0.144   Prob(JB):                        0.720
# Kurtosis:                       2.525   Cond. No.                         234.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """
